# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install opencv-python

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# **##### Reference URL https://docs.ultralytics.com/tasks/detect/**

# %%
# !pip install ultralytics -q

import ultralytics
ultralytics.checks()
from ultralytics import YOLO, settings
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.3/112.6 GB disk)

# %% [markdown]
# **##### Task:Detect, Mode:Train**
# -Hyperparameter : optimizer=auto/SGD/Adam/AdamW/NAdam/RAdam/RMSProp
# -Hyperparameter : name=name <-- /content/runs/detect/'name'

# %%
# !yolo task=detect mode=train model=yolov8m.pt data='/content/drive/MyDrive/tl_od_AF2_yolov8/dataset.yaml' imgsz=640 batch=5 epochs=30 iou=0.5 optimizer=auto
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#model = YOLO("yolov8m.pt")
#model.train(
#    data = "/content/drive/MyDrive/tl_od_AF2_yolov8/dataset.yaml",
#    imgsz = 640,
#    batch = 5,
#    epochs = 20,
#    optimizer="auto")

# %% [markdown]
# **##### Task:Detect, Mode:Predict**

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train2/weights/best.pt' source='/content/drive/MyDrive/tl_od_AF2_yolov8/TIS' classes=[0,1,2,3,4] imgsz=640 conf=0.35 iou=0.5 save=True save_txt=True
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/26 /content/drive/MyDrive/tl_od_AF2_yolov8/TIS/Road (201).jpg: 640x640 4 Cars, 2 Motorcycles, 37.0ms
# image 2/26 /content/drive/MyDrive/tl_od_AF2_yolov8/TIS/Road (202).jpg: 640x640 3 Cars, 3 Motorcycles, 1 Cycle, 37.0ms
# image 3/26 /content/drive/MyDrive/tl_od_AF2_yolov8/TIS/Road (203).jpg: 640x640 8 Cars, 2 Motorcycles, 37.0ms
# image 4/26 /content/drive/MyDrive/tl_od_AF2_yolov8/TIS/Road (204).jpg: 640x640 9 Cars, 1 Bus, 3 Motorcycles, 29.9ms
# image 5/26 /content/drive/MyDrive/tl_od_AF2_yolov8/TIS/Road (205).jpg: 640x640 8 Cars, 1 Bus, 2 Motorcycles, 1 Cycle, 29.9ms
# image 6/26 /content/drive/MyDrive/tl_od_AF2_yolov8/TIS/Road (206).jpg: 640x640 5 Cars, 1 Bus, 4 Motorcycles, 29.9ms
# ...

# %%
#model = YOLO("/content/runs/detect/train/weights/best.pt")
#model.predict(
#    "/content/drive/MyDrive/tl_od_AF2_yolov8/TIS",
#    classes=[0,1],
#    imgsz = 640,
#    conf = 0.9,
#    save = True,
#    save_txt = True)

# %% [markdown]
# **##### Setting the Runtime Session Directory**

# %%
base_dir = '/content/drive/MyDrive/tl_od_AF2_yolov8/'
RSD = os.path.join(base_dir, 'RSD')   # RSD : Runtime Session Directory

##### Update a setting
settings.update({'runs_dir': RSD})

##### Reset settings to default values
#settings.reset()
